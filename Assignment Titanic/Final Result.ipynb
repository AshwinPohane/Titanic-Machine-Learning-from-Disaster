# %%
import numpy as np
import pandas as pd
import mathplot as mt
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
dt = pd.read_csv("C:\\Users\\ashwi\.jupyter\\Jupyter Notebook\\Assignment Titanic\\train.csv")

# %%
dt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dt.drop (['PassengerId', 'Pclass', 'Name', 'Ticket', 'Cabin', 'SibSp', 'Parch', 'Embarked'], axis=1, inplace=True )

# %%
dt.head()
# Out:
#    Survived     Sex   Age     Fare
# 0         0    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         1  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         0    male  35.0   8.0500

# %%
dt.isnull().sum()
# Out:
# Survived      0
# Sex           0
# Age         177
# Fare          0
# dtype: int64

# %%
dt.mean().sum()
# Out:
# 62.2871639994718

# %%
dt['Age'].fillna(dt['Age'].mean(), inplace=True)

# %%
dt.head()
# Out:
#    Survived     Sex   Age     Fare
# 0         0    male  22.0   7.2500
# 1         1  female  38.0  71.2833
# 2         1  female  26.0   7.9250
# 3         1  female  35.0  53.1000
# 4         0    male  35.0   8.0500

# %%
dt.isnull().sum()
# Out:
# Survived    0
# Sex         0
# Age         0
# Fare        0
# dtype: int64

# %%
dt.head().count()
# Out:
# Survived    5
# Sex         5
# Age         5
# Fare        5
# dtype: int64

# %%
sex_dummies=pd.get_dummies(dt['Sex'],drop_first=True)

# %%
dt=pd.concat([dt,sex_dummies],axis=1)

# %%
dt.head()
# Out:
#    Survived       Age      Fare  male  male
# 0         0 -0.592481 -0.502445     1     1
# 1         1  0.638789  0.786845     0     0
# 2         1 -0.284663 -0.488854     0     0
# 3         1  0.407926  0.420730     0     0
# 4         0  0.407926 -0.486337     1     1

# %%
dt.drop (['Sex'], axis=1, inplace=True )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-509b8c89122a> in <module>
# ----> 1 dt.drop (['Sex'], axis=1, inplace=True )
#
# F:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# F:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
dt.head()
# Out:
#    Survived       Age      Fare  male  male
# 0         0 -0.592481 -0.502445     1     1
# 1         1  0.638789  0.786845     0     0
# 2         1 -0.284663 -0.488854     0     0
# 3         1  0.407926  0.420730     0     0
# 4         0  0.407926 -0.486337     1     1

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
feature_scale= ['Age', 'Fare']
dt[feature_scale]=ss.fit_transform(dt[feature_scale])

# %%
dt.head()
# Out:
#    Survived       Age      Fare  male  male
# 0         0 -0.592481 -0.502445     1     1
# 1         1  0.638789  0.786845     0     0
# 2         1 -0.284663 -0.488854     0     0
# 3         1  0.407926  0.420730     0     0
# 4         0  0.407926 -0.486337     1     1

# %%
x=dt.drop(['Survived'], axis=1)
y=dt['Survived']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# create parameter
model_param = {
    'DecisionTreeClassifier':{
        'model':DecisionTreeClassifier(),
        'param':{
            'criterion': ['gini','entropy']
        }
    },
        'KNeighborsClassifier':{
        'model':KNeighborsClassifier(),
        'param':{
            'n_neighbors': [5,10,15,20,25]
        }
    },
        'SVC':{
        'model':SVC(),
        'param':{
            'kernel':['rbf','linear','sigmoid'],
            'C': [0.1, 1, 10, 100]
         
        }
    }
}

# %%
scores =[]
for model_name, mp in model_param.items():
    model_selection = GridSearchCV(estimator=mp['model'],param_grid=mp['param'],cv=5,return_train_score=False)
    model_selection.fit(x,y)
    scores.append({
        'model': model_name,
        'best_score': model_selection.best_score_,
        'best_params': model_selection.best_params_
    })

# %%
data_model_score = pd.DataFrame(scores,columns=['model','best_score','best_params'])
data_model_score
# Out:
#                     model  best_score                  best_params
# 0  DecisionTreeClassifier    0.763248     {'criterion': 'entropy'}
# 1    KNeighborsClassifier    0.782330           {'n_neighbors': 5}
# 2                     SVC    0.796849  {'C': 100, 'kernel': 'rbf'}

# %%
model_svc = SVC( C= 100,kernel='rbf')

# %%
model_svc.fit(x, y)
# Out:
# SVC(C=100)

# %%
dt2 = pd.read_csv("C:\\Users\\ashwi\.jupyter\\Jupyter Notebook\\Assignment Titanic\\test.csv")

# %%
dt2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
dt3 =dt2.drop(['PassengerId','Name','Ticket','Cabin','Embarked','SibSp','Parch'], axis=1 )

# %%
dt3.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  34.5   7.8292
# 1       3  female  47.0   7.0000
# 2       2    male  62.0   9.6875
# 3       3    male  27.0   8.6625
# 4       3  female  22.0  12.2875

# %%
dt3.isnull().sum()
# Out:
# Pclass     0
# Sex        0
# Age       86
# Fare       1
# dtype: int64

# %%
dt3['Age'].fillna(dt3['Age'].mean(),inplace=True)

# %%
dt3.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  34.5   7.8292
# 1       3  female  47.0   7.0000
# 2       2    male  62.0   9.6875
# 3       3    male  27.0   8.6625
# 4       3  female  22.0  12.2875

# %%
dt3['Fare'].fillna(dt3['Fare'].mean(),inplace=True)

# %%
dt3.head()
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  34.5   7.8292
# 1       3  female  47.0   7.0000
# 2       2    male  62.0   9.6875
# 3       3    male  27.0   8.6625
# 4       3  female  22.0  12.2875

# %%
sex_dummies=pd.get_dummies(dt3['Sex'],drop_first=True)

# %%
dt3= pd.concat([dt3,sex_dummies],axis=1)
dt3.drop(['Sex'], axis=1, inplace=True )

# %%
dt3.head()
# Out:
#    Pclass   Age     Fare  male
# 0       3  34.5   7.8292     1
# 1       3  47.0   7.0000     0
# 2       2  62.0   9.6875     1
# 3       3  27.0   8.6625     1
# 4       3  22.0  12.2875     0

# %%
dt3[feature_scale] = ss.fit_transform(dt3[feature_scale])

# %%
dt3.head()
# Out:
#    Pclass       Age      Fare  male
# 0       3  0.334993 -0.498407     1
# 1       3  1.325530 -0.513274     0
# 2       2  2.514175 -0.465088     1
# 3       3 -0.259330 -0.483466     1
# 4       3 -0.655545 -0.418471     0

# %%
dt.head()
# Out:
#    Survived       Age      Fare  male  male
# 0         0 -0.592481 -0.502445     1     1
# 1         1  0.638789  0.786845     0     0
# 2         1 -0.284663 -0.488854     0     0
# 3         1  0.407926  0.420730     0     0
# 4         0  0.407926 -0.486337     1     1

# %%
dt.size
# Out:
# 4455

# %%
dt3.size
# Out:
# 1672

# %%
y_predicted = model_svc.predict(dt3)

# %%
submission = pd.DataFrame({
        "PassengerId": dt2['PassengerId'],
        "Survived": y_predicted
    })

# %%
submission.to_csv('titanic_submission_v02.csv', index=False)
